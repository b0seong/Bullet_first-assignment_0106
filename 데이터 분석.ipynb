# %%
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

b435 = fits.open('bullet_f435w_drz_sci.fits')
b_RMS_435 = fits.open('bullet_f435w_RMS.fits')
b814 = fits.open('bullet_f814w_drz_sci.fits')
b_RMS_814 = fits.open('bullet_f814w_RMS.fits')


data_b435 = b435[0].data
data_b_RMS_435 = b_RMS_435[0].data

fig = plt.imshow(data_b435, origin='lower', vmin=0, vmax=30)
plt.colorbar(fig)
plt.show()


fig = plt.imshow(data_b_RMS_435, origin='lower', vmin=20, vmax=30)
plt.colorbar(fig)
plt.show()

#b435_pd = pd.DataFrame(b435[0].data)
#b435_pd.to_csv('sample.csv')

# %%
np.set_printoptions(threshold=np.inf, linewidth=np.inf)
print(repr(b814[0].header))
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                 7013 / Axis length
# NAXIS2  =                 5100 / Axis length
# EXTEND  =                    T /Extensions may be present
# ORIGIN  = 'combDither, v1.47'  / FITS file originator
# DATE    = '2011-06-07T05:37:47Z'
# FILENAME= 'bullet_f814w_drz_sci.fits' / name of file
# FILETYPE= 'SCI     '
# TELESCOP= 'HST     '           / telescope used to acquire data
# INSTRUME= 'ACS     '           / identifier for instrument used to acquire data
# EXPTIME =               4944.0 / exposure duration (seconds)--calculated
# DETECTOR= 'WFC     '           / detector in use: WFC, HRC, or SBC
# FILTER1 = 'CLEAR1L '           / element selected from filter wheel 1
# FILTER2 = 'F814W   '           / element selected from filter wheel 2
# LRFWAVE =                  0.0 / proposed linear ramp filter wavelength
# ...

# %%
from astropy.io import ascii
import astropy
import pandas as pd

dat606 = fits.open('ellipticity_606.dat', unpack=False)

#print(astropy.table(dat606[1].data))
print(pd.DataFrame(dat606[1].data['E1']))
#print(dat606[1].data['E1'])
# Out:
#              0
# 0     0.000000
# 1     0.000000
# 2    -0.013998
# 3    -0.079975
# 4     0.141802
# ...        ...
# 4469  0.111718
# 4470  0.284894
# 4471  0.325547
# 4472  0.015079
# 4473 -0.453687
#
# [4474 rows x 1 columns]

# %%
print(repr(dat606[1].header))
# Out:
# XTENSION= 'BINTABLE'           /Binary table written by MWRFITS v1.6a
# BITPIX  =                    8 /Required value
# NAXIS   =                    2 /Required value
# NAXIS1  =                   56 /Number of bytes per row
# NAXIS2  =                 4474 /Number of rows
# PCOUNT  =                    0 /Normally 0 (no varying arrays)
# GCOUNT  =                    1 /Required value
# TFIELDS =                   15 /Number of columns in table
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# COMMENT
# COMMENT  *** Column names ***
# COMMENT
# TTYPE1  = 'ID      '           /
# TTYPE2  = 'X       '           /
# TTYPE3  = 'Y       '           /
# TTYPE4  = 'E1      '           /
# TTYPE5  = 'E2      '           /
# TTYPE6  = 'DE      '           /
# TTYPE7  = 'FLUX_RADIUS '       /
# TTYPE8  = 'A       '           /
# TTYPE9  = 'B       '           /
# TTYPE10 = 'THETA   '           /
# TTYPE11 = 'STATUS  '           /
# TTYPE12 = 'RA      '           /
# ...
